# %%
import pandas as pd
csdf=pd.read_csv("C:/Users/PRAGATI/Downloads/BankChurners.csv")

# %%
csdf.head()
# Out:
#     clientID               Type  age Gender  Dependent_count Education_Level  \
# 0  768805383  Existing Customer   45      M                3     High School
# 1  818770008  Existing Customer   49      F                5        Graduate
# 2  713982108  Existing Customer   51      M                3        Graduate
# 3  769911858  Existing Customer   40      F                4     High School
# 4  709106358  Existing Customer   40      M                3      Uneducated
#
#   Marital_Status Income_Category Card_Category  Months_on_book  ...  \
# 0        Married     $60K - $80K          Blue              39  ...
# 1         Single  Less than $40K          Blue              44  ...
# 2        Married    $80K - $120K          Blue              36  ...
# 3        Unknown  Less than $40K          Blue              34  ...
# 4        Married     $60K - $80K          Blue              21  ...
#
#    Months_Inactive_12_mon  Contacts_Count_12_mon  Credit_Limit  \
# ...

# %%
csdf.tail
# Out:
# <bound method NDFrame.tail of         clientID               Type  age Gender  Dependent_count  \
# 0      768805383  Existing Customer   45      M                3
# 1      818770008  Existing Customer   49      F                5
# 2      713982108  Existing Customer   51      M                3
# 3      769911858  Existing Customer   40      F                4
# 4      709106358  Existing Customer   40      M                3
# ...          ...                ...  ...    ...              ...
# 10122  772366833  Existing Customer   50      M                2
# 10123  710638233  Attrited Customer   41      M                2
# 10124  716506083  Attrited Customer   44      F                1
# 10125  717406983  Attrited Customer   30      M                2
# 10126  714337233  Attrited Customer   43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# ...

# %%
csdf.shape
# Out:
# (10127, 21)

# %%
csdf.columns
# Out:
# Index(['clientID', 'Type', 'age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
csdf.dtypes
# Out:
# clientID                      int64
# Type                         object
# age                           int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
csdf.count()
# Out:
# clientID                    10127
# Type                        10127
# age                         10127
# Gender                      10127
# Dependent_count             10127
# Education_Level             10127
# Marital_Status              10127
# Income_Category             10127
# Card_Category               10127
# Months_on_book              10127
# Total_Relationship_Count    10127
# Months_Inactive_12_mon      10127
# Contacts_Count_12_mon       10127
# Credit_Limit                10127
# Total_Revolving_Bal         10127
# Avg_Open_To_Buy             10127
# Total_Amt_Chng_Q4_Q1        10127
# Total_Trans_Amt             10127
# Total_Trans_Ct              10127
# Total_Ct_Chng_Q4_Q1         10127
# Avg_Utilization_Ratio       10127
# dtype: int64

# %%
csdf.info
# Out:
# <bound method DataFrame.info of         clientID               Type  age Gender  Dependent_count  \
# 0      768805383  Existing Customer   45      M                3
# 1      818770008  Existing Customer   49      F                5
# 2      713982108  Existing Customer   51      M                3
# 3      769911858  Existing Customer   40      F                4
# 4      709106358  Existing Customer   40      M                3
# ...          ...                ...  ...    ...              ...
# 10122  772366833  Existing Customer   50      M                2
# 10123  710638233  Attrited Customer   41      M                2
# 10124  716506083  Attrited Customer   44      F                1
# 10125  717406983  Attrited Customer   30      M                2
# 10126  714337233  Attrited Customer   43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# ...

# %%
A=csdf.sort_values(by='Gender')

# %%
A
# Out:
#        clientID               Type  age Gender  Dependent_count  \
# 5063  778912683  Existing Customer   51      F                2
# 5889  714031083  Attrited Customer   46      F                3
# 5888  779252283  Existing Customer   47      F                4
# 5886  718975083  Attrited Customer   47      F                4
# 5885  714287583  Attrited Customer   41      F                3
# ...         ...                ...  ...    ...              ...
# 2305  804310758  Existing Customer   58      M                3
# 2306  792912708  Existing Customer   45      M                5
# 6233  721012983  Existing Customer   46      M                3
# 6230  717841683  Existing Customer   49      M                3
# 0     768805383  Existing Customer   45      M                3
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 5063        Graduate         Single         Unknown          Blue
# ...

# %%
A = csdf.sort_values(by=['Type', 'age'], ascending=False)

# %%
A
# Out:
#        clientID               Type  age Gender  Dependent_count  \
# 251   715952883  Existing Customer   73      M                0
# 254   787348608  Existing Customer   70      M                0
# 151   712720158  Existing Customer   68      M                1
# 177   717296808  Existing Customer   67      F                1
# 320   778286433  Existing Customer   67      M                0
# ...         ...                ...  ...    ...              ...
# 1655  713259858  Attrited Customer   26      M                0
# 1752  804668658  Attrited Customer   26      F                0
# 1999  789777408  Attrited Customer   26      F                0
# 2265  787463508  Attrited Customer   26      M                0
# 2284  710586483  Attrited Customer   26      F                0
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 251      High School        Married     $40K - $60K          Blue
# ...

# %%
csdf.sum()
# Out:
# clientID                                                        7485651619341
# Type                        Existing CustomerExisting CustomerExisting Cus...
# age                                                                    469143
# Gender                      MFMFMMMMMMMMMMFMMMMFMFMFMFMMFMMMMFMFFFFFMMFMFM...
# Dependent_count                                                         23760
# Education_Level             High SchoolGraduateGraduateHigh SchoolUneducat...
# Marital_Status              MarriedSingleMarriedUnknownMarriedMarriedMarri...
# Income_Category             $60K - $80KLess than $40K$80K - $120KLess than...
# Card_Category               BlueBlueBlueBlueBlueBlueGoldSilverBlueBlueBlue...
# Months_on_book                                                         363847
# Total_Relationship_Count                                                38610
# Months_Inactive_12_mon                                                  23709
# ...

# %%
csdf.max()
# Out:
# clientID                            828343083
# Type                        Existing Customer
# age                                        73
# Gender                                      M
# Dependent_count                             5
# Education_Level                       Unknown
# Marital_Status                        Unknown
# Income_Category                       Unknown
# Card_Category                          Silver
# Months_on_book                             56
# Total_Relationship_Count                    6
# Months_Inactive_12_mon                      6
# Contacts_Count_12_mon                       6
# Credit_Limit                          34516.0
# Total_Revolving_Bal                      2517
# Avg_Open_To_Buy                       34516.0
# Total_Amt_Chng_Q4_Q1                    3.397
# Total_Trans_Amt                         18484
# Total_Trans_Ct                            139
# Total_Ct_Chng_Q4_Q1                     3.714
# ...

# %%
csdf.min()
# Out:
# clientID                            708082083
# Type                        Attrited Customer
# age                                        26
# Gender                                      F
# Dependent_count                             0
# Education_Level                       College
# Marital_Status                       Divorced
# Income_Category                       $120K +
# Card_Category                            Blue
# Months_on_book                             13
# Total_Relationship_Count                    1
# Months_Inactive_12_mon                      0
# Contacts_Count_12_mon                       0
# Credit_Limit                           1438.3
# Total_Revolving_Bal                         0
# Avg_Open_To_Buy                           3.0
# Total_Amt_Chng_Q4_Q1                      0.0
# Total_Trans_Amt                           510
# Total_Trans_Ct                             10
# Total_Ct_Chng_Q4_Q1                       0.0
# ...

# %%
csdf.count()
# Out:
# clientID                    10127
# Type                        10127
# age                         10127
# Gender                      10127
# Dependent_count             10127
# Education_Level             10127
# Marital_Status              10127
# Income_Category             10127
# Card_Category               10127
# Months_on_book              10127
# Total_Relationship_Count    10127
# Months_Inactive_12_mon      10127
# Contacts_Count_12_mon       10127
# Credit_Limit                10127
# Total_Revolving_Bal         10127
# Avg_Open_To_Buy             10127
# Total_Amt_Chng_Q4_Q1        10127
# Total_Trans_Amt             10127
# Total_Trans_Ct              10127
# Total_Ct_Chng_Q4_Q1         10127
# Avg_Utilization_Ratio       10127
# dtype: int64

# %%
csdf.groupby(by='clientID').count()
# Out:
#            Type  age  Gender  Dependent_count  Education_Level  \
# clientID
# 708082083     1    1       1                1                1
# 708083283     1    1       1                1                1
# 708084558     1    1       1                1                1
# 708085458     1    1       1                1                1
# 708086958     1    1       1                1                1
# ...         ...  ...     ...              ...              ...
# 828288333     1    1       1                1                1
# 828291858     1    1       1                1                1
# 828294933     1    1       1                1                1
# 828298908     1    1       1                1                1
# 828343083     1    1       1                1                1
#
#            Marital_Status  Income_Category  Card_Category  Months_on_book  \
# clientID
# 708082083               1                1              1               1
# ...

# %%
csdf.groupby(by=['clientID','Education_Level']).sum()
# Out:
#                                         Type  age Gender  Dependent_count  \
# clientID  Education_Level
# 708082083 High School      Existing Customer   45      F                3
# 708083283 Unknown          Attrited Customer   58      M                0
# 708084558 Doctorate        Attrited Customer   46      M                3
# 708085458 Uneducated       Existing Customer   34      F                2
# 708086958 Uneducated       Existing Customer   49      F                2
# ...                                      ...  ...    ...              ...
# 828288333 Uneducated       Existing Customer   50      M                0
# 828291858 College          Attrited Customer   38      M                3
# 828294933 High School      Attrited Customer   49      F                3
# 828298908 Graduate         Existing Customer   54      M                4
# 828343083 High School      Existing Customer   43      F                4
#
# ...

# %%
csdf.tail(10)
# Out:
#         clientID               Type  age Gender  Dependent_count  \
# 10117  712503408  Existing Customer   57      M                2
# 10118  713755458  Attrited Customer   50      M                1
# 10119  716893683  Attrited Customer   55      F                3
# 10120  710841183  Existing Customer   54      M                1
# 10121  713899383  Existing Customer   56      F                1
# 10122  772366833  Existing Customer   50      M                2
# 10123  710638233  Attrited Customer   41      M                2
# 10124  716506083  Attrited Customer   44      F                1
# 10125  717406983  Attrited Customer   30      M                2
# 10126  714337233  Attrited Customer   43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10117        Graduate        Married    $80K - $120K          Blue
# 10118         Unknown        Unknown    $80K - $120K          Blue
# ...

# %%
csdf.nunique
# Out:
# <bound method DataFrame.nunique of         clientID               Type  age Gender  Dependent_count  \
# 0      768805383  Existing Customer   45      M                3
# 1      818770008  Existing Customer   49      F                5
# 2      713982108  Existing Customer   51      M                3
# 3      769911858  Existing Customer   40      F                4
# 4      709106358  Existing Customer   40      M                3
# ...          ...                ...  ...    ...              ...
# 10122  772366833  Existing Customer   50      M                2
# 10123  710638233  Attrited Customer   41      M                2
# 10124  716506083  Attrited Customer   44      F                1
# 10125  717406983  Attrited Customer   30      M                2
# 10126  714337233  Attrited Customer   43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# ...

# %%
csdf['age'].unique()
# Out:
# array([45, 49, 51, 40, 44, 32, 37, 48, 42, 65, 56, 35, 57, 41, 61, 47, 62,
#        54, 59, 63, 53, 58, 55, 66, 50, 38, 46, 52, 39, 43, 64, 68, 67, 60,
#        73, 70, 36, 34, 33, 26, 31, 29, 30, 28, 27], dtype=int64)

# %%
csdf.isna().sum()
# Out:
# clientID                    0
# Type                        0
# age                         0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
csdf.iloc[:5,:2]
# Out:
#     clientID               Type
# 0  768805383  Existing Customer
# 1  818770008  Existing Customer
# 2  713982108  Existing Customer
# 3  769911858  Existing Customer
# 4  709106358  Existing Customer

# %%
csdf.loc[:5,['clientID','Type']]
# Out:
#     clientID               Type
# 0  768805383  Existing Customer
# 1  818770008  Existing Customer
# 2  713982108  Existing Customer
# 3  769911858  Existing Customer
# 4  709106358  Existing Customer
# 5  713061558  Existing Customer

# %%
cat=[]
con=[]

for i in csdf.columns:
    if csdf [i].dtypes=='object':
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['Type',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Income_Category',
#  'Card_Category']

# %%
con
# Out:
# ['clientID',
#  'age',
#  'Dependent_count',
#  'Months_on_book',
#  'Total_Relationship_Count',
#  'Months_Inactive_12_mon',
#  'Contacts_Count_12_mon',
#  'Credit_Limit',
#  'Total_Revolving_Bal',
#  'Avg_Open_To_Buy',
#  'Total_Amt_Chng_Q4_Q1',
#  'Total_Trans_Amt',
#  'Total_Trans_Ct',
#  'Total_Ct_Chng_Q4_Q1',
#  'Avg_Utilization_Ratio']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.title('count credit card')
import seaborn as sns
sns.countplot(x="Income_Category",data=csdf)
# Out:
# <Axes: title={'center': 'count credit card'}, xlabel='Income_Category', ylabel='count'>

# %%
plt.figure(figsize=(3,2))
plt.hist(A['Total_Trans_Ct'],edgecolor="red")
# Out:
# (array([ 187., 1074., 1658., 1246., 2267., 2289.,  757.,  331.,  275.,
#           43.]),
#  array([ 10. ,  22.9,  35.8,  48.7,  61.6,  74.5,  87.4, 100.3, 113.2,
#         126.1, 139. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
plt.pie(x,labels=x.index,autopct="%d%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x26ec6a219a0>,
# ...
#  [Text(0.4056539532570433, 1.0224699849907246, '3'),
#   Text(-1.0622456001250455, -0.28571714161908834, '2'),
#   Text(0.43121559433431866, -1.0119550934714943, '1'),
#   Text(1.0369160768326395, -0.36715807168848674, '4'),
#   Text(1.0876241348650058, -0.16454100175685174, '5'),
#   Text(1.098247215805508, -0.062072964932004905, '6'),
#   Text(1.0999554861234044, -0.009895885358333491, '0')],
#  [Text(0.22126579268565996, 0.5577109009040315, '37%'),
#   Text(-0.5794066909772975, -0.1558457136104118, '32%'),
#   Text(0.23520850600053742, -0.5519755055299058, '22%'),
#   Text(0.5655905873632578, -0.20026803910281094, '4%'),
#   Text(0.5932495281081849, -0.08974963732191912, '1%'),
#   Text(0.5990439358939135, -0.033857980872002674, '1%'),
#   Text(0.599975719703675, -0.005397755650000086, '0%')])

# %%
x=csdf['Months_Inactive_12_mon'].value_counts()

# %%
x
# Out:
# Months_Inactive_12_mon
# 3    3846
# 2    3282
# 1    2233
# 4     435
# 5     178
# 6     124
# 0      29
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.scatter(csdf['Credit_Limit'],csdf['clientID'])
plt.show()

# %%
import pandas as pd
cross_tab=pd.crosstab(csdf['age'],csdf['Gender'])

# %%
cross_tab

# %%
# Out:
# <Axes: xlabel='Total_Trans_Amt', ylabel='Total_Revolving_Bal'>

# %%
csdf[['clientID',
 'age',
 'Dependent_count',
 'Months_on_book',
 'Total_Relationship_Count',
 'Months_Inactive_12_mon',
 'Contacts_Count_12_mon',
 'Credit_Limit',
 'Total_Revolving_Bal']].corr()
# Out:
#                           clientID       age  Dependent_count  Months_on_book  \
# clientID                  1.000000  0.007613         0.006772        0.134588
# age                       0.007613  1.000000        -0.122254        0.788912
# Dependent_count           0.006772 -0.122254         1.000000       -0.103062
# Months_on_book            0.134588  0.788912        -0.103062        1.000000
# Total_Relationship_Count  0.006907 -0.010931        -0.039076       -0.009203
# Months_Inactive_12_mon    0.005729  0.054361        -0.010768        0.074164
# Contacts_Count_12_mon     0.005694 -0.018452        -0.040505       -0.010774
# Credit_Limit              0.005708  0.002476         0.068065        0.007507
# Total_Revolving_Bal       0.000825  0.014780        -0.002688        0.008623
#
#                           Total_Relationship_Count  Months_Inactive_12_mon  \
# clientID                                  0.006907                0.005729
# ...

# %%
sns.pairplot(csdf[['clientID',
 'age',
 'Dependent_count',
 'Months_on_book',
 'Total_Relationship_Count']])
